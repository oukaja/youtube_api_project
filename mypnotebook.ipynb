# %% [markdown]
# # Analyse descriptive des données de Youtube

# %% [markdown]
# ## En utilisant Youtube API de Python, Nous avons développés un programme qui prend en entrée le ID d’une vidéo (ex : vH2eZAM30s), récupère tous les commentaires apparus sous cette vidéo et les stocke dans une base de données MongoDB. Ce programme permet les fonctionnalités suivantes :

# %% [markdown]
# ### L'importation du Module développé:

# %%
import modyoutubeproject as myp

# %% [markdown]
# ### Premièrement, On Récupére l'id de la vidéo :

# %%
myp.id_video(id="hDJdkcdG1iA")

# %% [markdown]
# ### Chargement des données de la video :

# %%
myp.recharger_les_donnees()

# %% [markdown]
# ### 1-Retourner le nombre de commentaires pour la vidéo donnée :

# %%
myp.nombre_de_commentaire()
# Out:
# nombre de commentaire : 73

# %% [markdown]
# ### 2-En utilisant la métrique « snippet.likeCount », retourner le commentaire le plus populaire, ceux qui font partie du 1er quartile:

# %%
myp.commentaire_le_plus_populaire_du_premier_Q1()
# Out:
# Nombre de j'aime : 21
# Texte  : Wow this is the greatest explanation ever precise and accurate!

# %% [markdown]
# ### 3-Retourner les 10 termes les plus fréquents parmi les commentaires et les afficher avec leurs fréquences, en utilisant un outil de visualisation adéquat (ex : Bar chart )

# %%
myp.dix_termes_les_plus_frequent()

# %% [markdown]
# ### 4- Reçoit en entrée une expression (un terme) et retourne :
#
#     a. Sa fréquence dans le dataset traité
#
#     b. Combien en moyenne cette expression est citée dans un commentaire

# %%
myp.frequence_par_terme_en_entree(terme="video")
# Out:
# a - fréquence dans le dataset traité  154
# b - moyenne cette expression est citée dans un commentaire 3.08

# %% [markdown]
# ### 5 - Prend en entrée deux expressions E et F et calcule la probabilité conditionnelle que l’expression E apparaisse dans un commentaire sachant que l’expression F y est citée

# %%
myp.proba_conditionnel_A_sachant_B(A="video",B="business intelligence ")
# Out:
# proba de B sachant A vaut :  0.52

# %% [markdown]
# ### 6- Proposer et implémenter une démarche pour calculer le pourcentage des commentaires publiés par des femmes et celui des commentaires publiés par des hommes:

# %%
myp.pourcentage_sexe()
# Out:
# pourcentage des commentaires publiés par les femmes : 21.74%
# pourcentage des commentaires publiés par les hommes : 78.26%

# %% [markdown]
# ### Pour le Transfer des commantaires et la recuperation du MongoDB se fait par :

# %%
myp.commentaire_vers_mongodb()

# %%
myp.commentaire_de_mongodb()
# Out:
# grab best deal on flipkart up to 80 off the big billion days.
#
# those glasses 👌👌.
# ততনগঝগ.
# find out why the hoverfly hoverboard was named a top tech gift by huffington post and inc.
# interdicting view.
# awesom video mate your video rock the floor awesome jobthumsup👍👍👍👍.
# but i have 2020 vision why would i want to wear glasses.
# hii i am started my new youtube channelfor new and upgrated videos subsribe my youtube channel.
# good boss.
# so bi is basically the opposite of bs.
# interesting. i have just bought for the first time a new brand of coffee. now if the company had depended on past historic data only they would have sent me loads of offers on my old brand. however if they had realised that i thought it was a cheap variety they would have realised how i was getting more open to alternatives my committment to the brand as opposed to loyalty had weakened. with that perception data they could have moderated their bi.
# ...
